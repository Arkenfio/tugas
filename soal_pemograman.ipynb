# %% [markdown]
# <a href="https://colab.research.google.com/github/Arkenfio/tugas/blob/main/soal_pemograman.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![tugas1.jpg](data:image/jpeg;base64,...)![tugas3.jpg](data:image/jpeg;base64,...)![tugas2.jpg](data:image/jpeg;base64,...)![tugas4.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Tugas Pemograman : Senin-7-Oktober-2024
# Tugas soal dan jawaban
