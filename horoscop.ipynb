# %% [markdown]
# <a href="https://colab.research.google.com/github/Arkenfio/tugas/blob/main/horoscop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
mobil1 = input ("masukkan mobil anda :")
mobil2 = input ("masukkan mobil anda :")

kotor = bool(mobil1) and bool (mobil2)

print (f"apakah {mobil1} dan {mobil2} bersih? {kotor}")
# Out:
# masukkan mobil anda :tes
# masukkan mobil anda :tes
# apakah tes dan tes bersih? True
