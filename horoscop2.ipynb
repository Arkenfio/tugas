# %% [markdown]
# <a href="https://colab.research.google.com/github/Arkenfio/tugas/blob/main/horoscop2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 nama_pedofil = input("siapa yg paling pedofil :")
pedofil = input("mangsa :")
persen = input("berapa persen :")
hasil = (nama_pedofil + " dipastikan anda pedofil" + pedofil + " sebesar "+ persen +"%")
print(hasil)
# Out:
# siapa yg paling pedofil :teas
